# %%
# Each print statement starts on a new Line

print( 'Hello there. ' )
print( 'My name is...' )
print('AnupKelkar' )
# Out:
# Hello there.
# My name is...
# AnupKelkar

# %%
# Including end=' ' keeps output on same Line
print( 'Hello there.',end= ' ' )
print( 'My name is... ' ,end=' ' )
print( 'Anup' )
# Out:
# Hello there. My name is...  Anup

# %%
wage = 24

print( 'Wage is',end=' ' )
print(wage) # print variable's value
print('Goodbye')
# Out:
# Wage is 24
# Goodbye

# %%
wage = 20

print( 'Wage:', wage ) # Comma separates multiple items
print('Goodbye.')
# Out:
# Wage: 20
# Goodbye.

# %%
print( '1\n2\n3')
# Out:
# 1
# 2
# 3

# %%
print( '123 ')
print()
print( 'abc')
# Out:
# 123
#
# abc

# %% [markdown]
# ### Input Function

# %%
print( 'Enter name of best friend:')
best_friend = input()
print('My best friend is', best_friend)
# Out:
# Enter name of best friend:
# My best friend is ANup

# %%
my_string = '123'
my_int=int('123' )

print(my_string)
print(my_int)
# Out:
# 123
# 123

# %%
print( 'Enter wage:' )
wage = int(input())
print('Wage is', wage)

new_wage = wage + 10
print('New wage:', new_wage )
# Out:
# Enter wage:
# Wage is 50
# New wage: 60

# %%
hours = 40
weeks = 52
hourly_wage = int(input('Enter hourly wage: '))
print( 'Hourly wage is', hourly_wage )
print( 'Annual salary is', hourly_wage * hours * weeks )
# Out:
# Hourly wage is 20
# Annual salary is 41600

# %% [markdown]
# ## Errors

# %%
print('Current salary is' , end=' ')
print(45000)
# Out:
# Current salary is 45000

# %%
print('Enter new salary: ',end=' ' )
new_sal = int(input())
print('Enter number:',end=' ' )
user_num = int(input())
# Out:
# Enter new salary:  Enter number:

# %%
print(new_sal)print(user_num)
# Out:
#   Cell In[1], line 1
#     print(new_sal)print(user_num)
#                   ^
# SyntaxError: invalid syntax

# %%
print(new_sal)

print(user_num)
# Out:
# 45000
# 34

# %%
print( 'Salary is',end=' ')
print(20*40*50)
# Out:
# Salary is 40000

# %%
print('Enter integer:', end=' ')
user_num = int(input())
print(user_num)
# Out:
# Enter integer:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 2
#       1 print('Enter integer:', end=' ')
# ----> 2 user_num = int(input())
#       3 print(user_num)
#
# ValueError: invalid literal for int() with base 10: 'hk'

# %%
print('Enter integer:', end=' ')
user_num = int(input())
print(user_num)
## pass the input as 'Anup'
# Out:
# Enter integer:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 2
#       1 print('Enter integer:', end=' ')
# ----> 2 user_num = int(input())
#       3 print(user_num)
#       4 ## pass the input as 'Anup'
#
# ValueError: invalid literal for int() with base 10: 'anup'

# %% [markdown]
# ## Logical Error

# %%
current_salary = int(input('Enter current salary: ' ) )
raise_percentage = 5 # Logic error gives a 500% raise instead of 5%
new_salary = current_salary+(current_salary * raise_percentage)
print( 'New salary:' , new_salary)
# Out:
# New salary: 60000

# %%
current_salary = int(input('Enter current salary: ' ) )
raise_percentage = 0.05 # 5% raise
new_salary = current_salary+(current_salary * raise_percentage)
print( 'New salary:' , new_salary)
# Out:
# New salary: 10500.0

# %% [markdown]
# ## Python example: Salary calculation

# %%
hourly_wage = 20

print('Annua1 salary is: ')
print(hourly_wage * 40 * 50)
print('Monthly salary is: ')
print(((hourly_wage *40 * 50) / 12))
print()

## FIXME: The above is worng. change
##       the 1 so that the statement
##       outputs monthly salary.
# Out:
# Annua1 salary is:
# 40000
# Monthly salary is:
# 3333.3333333333335
