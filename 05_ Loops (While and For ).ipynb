# %%
l = [-9, -47, -6, -21, 3, -25, -23]
counter = 0
i=0

for i in l:
    if i < 0:
        counter = counter + 1
print ("counter:" , counter)
# Out:
# counter: 6

# %%
curr_power = 2
user_char = input( ' Enter either "y" or "n" :')

while user_char =='y':
    print(curr_power)
    curr_power = curr_power * 2
    user_char = input( 'Enter either"y" or "n" :')

print( 'Done' )
# Out:
# 2
# 4
# Done

# %%
nose = ' 0 ' # Looks a little a nose
user_value = '_'

while user_value != 'q':
    print(f' {user_value} {user_value}' ) # Print eyes
    print(f' {nose}') # Print nose
    print(user_value*5)# print mouth
    print( '\n')

    # Get new character for eyes and mouth
    user_input = input("Enter a character ( 'q' for quit) : \n")
    user_value = user_input[0]

print( 'Goodbye. \n')
# Out:
#  _ _
#   0
# _____
#
#
#  # #
#   0
# #####
#
#
#  @ @
#   0
# @@@@@
#
#
# Goodbye.

# %%
# Read num from user ...
num = int(input( 'Enter number:'))
print("num:", num)

# print each digit
while num > 0:
    print(num % 10)
    num = num // 10
# Out:
# num: 902
# 2
# 0
# 9

# %% [markdown]
# ## More Example

# %%
n = int(input( 'Enter the value of n: ' ) )
print("n:", n)
result =1
i = 1
while i <= n:
  result = result * i
  print("i:", i, "result:", result )
  i += 1
print("factorial of", n, "is", result)
# Out:
# n: 5
# i: 1 result: 1
# i: 2 result: 2
# i: 3 result: 6
# i: 4 result: 24
# i: 5 result: 120
# factorial of 5 is 120

# %%
total = 0
counter =0
user_inp = int(input())
print("user_inp:", user_inp)

while user_inp > 0:   # Get values until 0 (or Less)
      total = total + user_inp
      counter = counter + 1
      user_inp = int(input())

print(f'Average: {total / counter:.2f}\n')
# Out:
# user_inp: 2
# Average: 3.00

# %% [markdown]
# ### Counting

# %%
# Iterating N times using a Loop variable

N = int(input( 'Enter the value: '))
print("N:", N)
i = 1
while i <= N:
    # Loop body statements go here
    print(i)
    i = i + 1
# Out:
# N: 5
# 1
# 2
# 3
# 4
# 5

# %%
i = 5
while i >= 1:
     # Loop body statements go here
    print(i)
    i= i - 1
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
i = 0

N = int(input( 'Enter the value of N:'))
print("N:", N  )
while i <= N:
    # Loop body statements go here
    print(i)
    i = i + 2
# Out:
# N: 10
# 0
# 2
# 4
# 6
# 8
# 10

# %% [markdown]
# ## For loop

# %%
channels = {
'MTV': 35,
'CNN': 28,
'FOX': 11,
'NBC': 4,
'CBS': 12,
}

for c in channels :
    print(f' {c} is on channel {channels[c]}')
# Out:
#  MTV is on channel 35
#  CNN is on channel 28
#  FOX is on channel 11
#  NBC is on channel 4
#  CBS is on channel 12

# %%
my_str = ''
for character in "Take me to the moon. " :
     my_str += character + '_'
print(my_str)
# Out:
# T_a_k_e_ _m_e_ _t_o_ _t_h_e_ _m_o_o_n_._ _

# %%
daily_revenues = [
2356,   # Monday
1800,   # Tuesday
1792,   # Wednesday
2058,   # Thursday
1988,   # Friday
2002,   # Saturday
1890    # Sunday
]

total = 0
for day in daily_revenues:
    total += day

    average= total / len(daily_revenues)

print(f'Week1y revenue: ${total: .2f}')
print(f'Dai1y average revenue: ${average:.2f}')
# Out:
# Week1y revenue: $ 13886.00
# Dai1y average revenue: $1983.71

# %% [markdown]
# ### range() function

# %%
# Generate numbers between 0 to 6
for i in range(6):
    print (i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
for num in range(1, 10, 2):
    print(num)
# Out:
# 1
# 3
# 5
# 7
# 9

# %% [markdown]
# ## Nested Loops

# %%
print( 'Two-letter domain names: ' )
letter1 = 'a'
letter2 = 'a'
while letter1 <= 'z':   # outer loop
  letter2 = 'a'
  while letter2 <= 'z' :  # Inner loop
    print(f'{letter1}{letter2}.com')
    letter2 = chr(ord(letter2) + 1)
  letter1 = chr(ord(letter1) + 1)
# Out:
# Two-letter domain names:
# aa.com
# ab.com
# ac.com
# ad.com
# ae.com
# af.com
# ag.com
# ah.com
# ai.com
# aj.com
# ak.com
# al.com
# am.com
# an.com
# ao.com
# ap.com
# aq.com
# ar.com
# as.com
# at.com
# au.com
# av.com
# aw.com
# ax.com
# ay.com
# az.com
# ba.com
# bb.com
# bc.com
# bd.com
# be.com
# bf.com
# bg.com
# bh.com
# bi.com
# bj.com
# bk.com
# bl.com
# bm.com
# bn.com
# bo.com
# bp.com
# bq.com
# br.com
# bs.com
# bt.com
# bu.com
# bv.com
# bw.com
# bx.com
# by.com
# bz.com
# ca.com
# cb.com
# cc.com
# cd.com
# ce.com
# cf.com
# cg.com
# ch.com
# ci.com
# cj.com
# ck.com
# cl.com
# cm.com
# cn.com
# co.com
# cp.com
# cq.com
# cr.com
# cs.com
# ct.com
# cu.com
# cv.com
# cw.com
# cx.com
# cy.com
# cz.com
# da.com
# db.com
# dc.com
# dd.com
# de.com
# df.com
# dg.com
# dh.com
# di.com
# dj.com
# dk.com
# dl.com
# dm.com
# dn.com
# do.com
# dp.com
# dq.com
# dr.com
# ds.com
# dt.com
# du.com
# dv.com
# dw.com
# dx.com
# dy.com
# dz.com
# ea.com
# eb.com
# ec.com
# ed.com
# ...

# %%
user_input = input('Enter phone number: ')

index = 0
for character in user_input:
    print(f' Element {index} is: {character} ')
    index += 1
# Out:
#  Element 0 is: 1
#  Element 1 is: -
#  Element 2 is: 5
#  Element 3 is: 5
#  Element 4 is: 5
#  Element 5 is: -
#  Element 6 is: H
#  Element 7 is: O
#  Element 8 is: L
#  Element 9 is: I
#  Element 10 is: D
#  Element 11 is: A
#  Element 12 is: Y

# %%
user_input = input( 'Enter phone number:')
print("user_input:", user_input)
phone_number =''

for character in user_input:
     if ( '0' <= character <= '9' ) or (character == '-' ):
          phone_number += character
     elif ( 'a' <= character <= 'c') or ('A' <= character <= 'C'):
          phone_number += '2' 
     #FIXME: Add remaining eLif branches
     else:
          phone_number += '?'

print(f'Numbers only: {phone_number} ' )
# Out:
# user_input: 1-555-HOLIDAY
# Numbers only: 1-555-?????2?

# %% [markdown]
# ## Break & Continue

# %%
for c in 'python' :
    print(c)
print( 'done ' )
# Out:
# p
# y
# t
# h
# o
# n
# done

# %%
for c in 'python':
    if c == 'P':
        break
    print (c)
print( 'done')
# Out:
# p
# y
# t
# h
# o
# n
# done

# %%
for c in 'python' :
  if c == 'P' :
     continue
  print(c)
print( 'done')
# Out:
# p
# y
# t
# h
# o
# n
# done

# %% [markdown]
# ### loop else

# %%
names = ['Jayesh' , 'Chetan' , 'Manish' , 'Varsha' , 'Jai']
num = int(input( 'Enter number of names to print: '))
print("num:", num)
for i in range(len(names)):
    if i == num:
        break
    print(names[i], end=' ')
else:
    print("All names printed.")
# Out:
# num: 6
# Jayesh Chetan Manish Varsha Jai All names printed.

# %% [markdown]
# ### enumerate()

# %%
origins = [4, 8, 10]

for index in range(len(origins)):
    value = origins[index]  # Retrieve value of element
    print(f' Element {index}: {value}' )
# Out:
#  Element 0: 4
#  Element 1: 8
#  Element 2: 10

# %%
origins = [4, 8, 10]

for (index, value) in enumerate(origins): 
    print(f'Element {index}: {value}')
# Out:
# Element 0: 4
# Element 1: 8
# Element 2: 10

# %%
for i in range(3):
    print(i)
# Out:
# 0
# 1
# 2

# %% [markdown]
# Convert to reverse binary
# Max Score: 10 | Difficulty: medium
#
# Write a program that takes in a positive integer as input, and outputs a string of 1's and 0's representing the integer in reverse binary.
#
# For an integer x, the algorithm is:
#
# As long as x is greater than 0
# Output x modulo 2 (remainder is either 0 or 1)
# Assign x with x divided by 2
# Note: The above algorithm outputs the 0's and 1's in reverse order.
#
# Ex: If the input is:
#
# 6
# the output is:
#
# 011
# 6 in binary is 110; the algorithm outputs the bits in reverse.

# %%
x = int(input("Enter a positive integer: "))
result = ""
while x > 0:
    result += str(x % 2)
    x = x // 2
print(result)
# Out:
# 011
